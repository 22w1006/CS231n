# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.365706
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.552807 analytic: -0.552807, relative error: 5.849982e-08
# numerical: -2.680281 analytic: -2.680281, relative error: 4.764217e-09
# numerical: -1.130191 analytic: -1.130191, relative error: 1.353620e-08
# numerical: -2.110860 analytic: -2.110860, relative error: 4.369930e-09
# numerical: 2.840257 analytic: 2.840257, relative error: 1.400941e-08
# numerical: 0.274936 analytic: 0.274936, relative error: 8.627336e-08
# numerical: -5.650465 analytic: -5.650465, relative error: 1.065226e-09
# numerical: -1.339599 analytic: -1.339599, relative error: 2.204695e-09
# numerical: 0.396386 analytic: 0.396386, relative error: 1.192339e-07
# numerical: 3.220608 analytic: 3.220608, relative error: 1.029753e-08
# numerical: 0.331286 analytic: 0.331286, relative error: 6.570815e-08
# numerical: 1.523216 analytic: 1.523216, relative error: 1.475386e-08
# numerical: -0.308746 analytic: -0.308746, relative error: 2.043770e-07
# numerical: 1.170066 analytic: 1.170066, relative error: 1.218877e-08
# numerical: 0.187041 analytic: 0.187041, relative error: 2.203305e-07
# numerical: -0.489613 analytic: -0.489613, relative error: 2.435073e-08
# numerical: 0.092802 analytic: 0.092802, relative error: 2.710495e-07
# numerical: 3.373668 analytic: 3.373668, relative error: 3.328651e-10
# numerical: 2.044802 analytic: 2.044802, relative error: 1.036562e-08
# numerical: 1.165978 analytic: 1.165978, relative error: 2.590495e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.365706e+00 computed in 0.078287s
# vectorized loss: 2.365706e+00 computed in 0.008773s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr_factor in range(16, 23, 2):
    for r in range(22000, 26100, 1000):
        lr = 1e-7 * (lr_factor/10)
        softmax = Softmax()
        softmax.train(X_train, y_train, learning_rate=lr, reg=r, num_iters=1500, verbose=True)
        train_acc = np.mean(y_train == softmax.predict(X_train))
        val_acc = np.mean(y_val == softmax.predict(X_val)) 
        results[(lr, r)] = (train_acc, val_acc)
        if val_acc > best_val:
            best_val = val_acc
            best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 680.796870
# iteration 100 / 1500: loss 166.238990
# iteration 200 / 1500: loss 41.932947
# iteration 300 / 1500: loss 11.711923
# iteration 400 / 1500: loss 4.430397
# iteration 500 / 1500: loss 2.624222
# iteration 600 / 1500: loss 2.187122
# iteration 700 / 1500: loss 2.126614
# iteration 800 / 1500: loss 2.111077
# iteration 900 / 1500: loss 2.122066
# iteration 1000 / 1500: loss 2.096029
# iteration 1100 / 1500: loss 2.137856
# iteration 1200 / 1500: loss 2.093410
# iteration 1300 / 1500: loss 2.077909
# iteration 1400 / 1500: loss 2.130318
# iteration 0 / 1500: loss 708.461050
# iteration 100 / 1500: loss 162.325538
# iteration 200 / 1500: loss 38.466270
# iteration 300 / 1500: loss 10.359692
# iteration 400 / 1500: loss 3.978929
# iteration 500 / 1500: loss 2.438140
# iteration 600 / 1500: loss 2.169479
# iteration 700 / 1500: loss 2.065874
# iteration 800 / 1500: loss 2.118376
# iteration 900 / 1500: loss 2.058949
# iteration 1000 / 1500: loss 2.108238
# iteration 1100 / 1500: loss 2.085623
# iteration 1200 / 1500: loss 2.060416
# iteration 1300 / 1500: loss 2.082982
# iteration 1400 / 1500: loss 2.030971
# iteration 0 / 1500: loss 746.033744
# iteration 100 / 1500: loss 160.320371
# iteration 200 / 1500: loss 35.847438
# iteration 300 / 1500: loss 9.349327
# iteration 400 / 1500: loss 3.649475
# iteration 500 / 1500: loss 2.425512
# iteration 600 / 1500: loss 2.131155
# iteration 700 / 1500: loss 2.079756
# iteration 800 / 1500: loss 2.059952
# iteration 900 / 1500: loss 2.039472
# iteration 1000 / 1500: loss 2.095193
# iteration 1100 / 1500: loss 2.079281
# iteration 1200 / 1500: loss 2.126033
# iteration 1300 / 1500: loss 2.091734
# iteration 1400 / 1500: loss 2.078543
# iteration 0 / 1500: loss 757.669231
# iteration 100 / 1500: loss 152.786939
# iteration 200 / 1500: loss 32.153292
# iteration 300 / 1500: loss 8.143817
# iteration 400 / 1500: loss 3.198499
# iteration 500 / 1500: loss 2.355128
# iteration 600 / 1500: loss 2.162640
# iteration 700 / 1500: loss 2.057559
# iteration 800 / 1500: loss 2.073531
# iteration 900 / 1500: loss 2.064800
# iteration 1000 / 1500: loss 2.105195
# iteration 1100 / 1500: loss 2.028522
# iteration 1200 / 1500: loss 2.117931
# iteration 1300 / 1500: loss 2.030613
# iteration 1400 / 1500: loss 2.102178
# iteration 0 / 1500: loss 803.028762
# iteration 100 / 1500: loss 151.838914
# iteration 200 / 1500: loss 30.060147
# iteration 300 / 1500: loss 7.350147
# iteration 400 / 1500: loss 3.092081
# iteration 500 / 1500: loss 2.288950
# iteration 600 / 1500: loss 2.084640
# iteration 700 / 1500: loss 2.103195
# iteration 800 / 1500: loss 2.094148
# iteration 900 / 1500: loss 2.054085
# iteration 1000 / 1500: loss 2.058256
# iteration 1100 / 1500: loss 2.091235
# iteration 1200 / 1500: loss 2.110391
# iteration 1300 / 1500: loss 2.090380
# iteration 1400 / 1500: loss 2.107619
# iteration 0 / 1500: loss 676.512415
# iteration 100 / 1500: loss 138.720370
# iteration 200 / 1500: loss 29.809202
# iteration 300 / 1500: loss 7.718937
# iteration 400 / 1500: loss 3.262764
# iteration 500 / 1500: loss 2.370789
# iteration 600 / 1500: loss 2.122916
# iteration 700 / 1500: loss 2.036356
# iteration 800 / 1500: loss 2.042069
# iteration 900 / 1500: loss 2.051712
# iteration 1000 / 1500: loss 2.030496
# iteration 1100 / 1500: loss 2.054630
# iteration 1200 / 1500: loss 2.053890
# iteration 1300 / 1500: loss 2.117927
# iteration 1400 / 1500: loss 2.037900
# iteration 0 / 1500: loss 708.314250
# iteration 100 / 1500: loss 135.035172
# iteration 200 / 1500: loss 27.171886
# iteration 300 / 1500: loss 6.821693
# iteration 400 / 1500: loss 2.968681
# iteration 500 / 1500: loss 2.225001
# iteration 600 / 1500: loss 2.145718
# iteration 700 / 1500: loss 2.105015
# iteration 800 / 1500: loss 2.081388
# iteration 900 / 1500: loss 2.079344
# iteration 1000 / 1500: loss 2.089475
# iteration 1100 / 1500: loss 2.067008
# iteration 1200 / 1500: loss 2.144725
# iteration 1300 / 1500: loss 2.069495
# iteration 1400 / 1500: loss 2.081633
# iteration 0 / 1500: loss 740.609295
# iteration 100 / 1500: loss 131.374928
# iteration 200 / 1500: loss 24.613263
# iteration 300 / 1500: loss 6.056933
# iteration 400 / 1500: loss 2.784165
# iteration 500 / 1500: loss 2.144548
# iteration 600 / 1500: loss 2.101479
# iteration 700 / 1500: loss 2.142489
# iteration 800 / 1500: loss 2.044038
# iteration 900 / 1500: loss 2.154304
# iteration 1000 / 1500: loss 2.066254
# iteration 1100 / 1500: loss 2.149999
# iteration 1200 / 1500: loss 2.064499
# iteration 1300 / 1500: loss 2.150171
# iteration 1400 / 1500: loss 2.067128
# iteration 0 / 1500: loss 775.712362
# iteration 100 / 1500: loss 128.011436
# iteration 200 / 1500: loss 22.595989
# iteration 300 / 1500: loss 5.376268
# iteration 400 / 1500: loss 2.657699
# iteration 500 / 1500: loss 2.158345
# iteration 600 / 1500: loss 2.153452
# iteration 700 / 1500: loss 2.103818
# iteration 800 / 1500: loss 2.059036
# iteration 900 / 1500: loss 2.087378
# iteration 1000 / 1500: loss 2.070877
# iteration 1100 / 1500: loss 2.063176
# iteration 1200 / 1500: loss 2.092505
# iteration 1300 / 1500: loss 2.107424
# iteration 1400 / 1500: loss 2.120377
# iteration 0 / 1500: loss 802.708237
# iteration 100 / 1500: loss 123.354529
# iteration 200 / 1500: loss 20.469719
# iteration 300 / 1500: loss 4.880203
# iteration 400 / 1500: loss 2.510761
# iteration 500 / 1500: loss 2.152345
# iteration 600 / 1500: loss 2.096916
# iteration 700 / 1500: loss 2.104348
# iteration 800 / 1500: loss 2.083567
# iteration 900 / 1500: loss 2.140107
# iteration 1000 / 1500: loss 2.057251
# iteration 1100 / 1500: loss 2.152041
# iteration 1200 / 1500: loss 2.081653
# iteration 1300 / 1500: loss 2.105996
# iteration 1400 / 1500: loss 2.063131
# iteration 0 / 1500: loss 678.442171
# iteration 100 / 1500: loss 116.402090
# iteration 200 / 1500: loss 21.490023
# iteration 300 / 1500: loss 5.398517
# iteration 400 / 1500: loss 2.654296
# iteration 500 / 1500: loss 2.207952
# iteration 600 / 1500: loss 2.055385
# iteration 700 / 1500: loss 2.076896
# iteration 800 / 1500: loss 2.063686
# iteration 900 / 1500: loss 2.066141
# iteration 1000 / 1500: loss 2.094121
# iteration 1100 / 1500: loss 2.080252
# iteration 1200 / 1500: loss 2.045945
# iteration 1300 / 1500: loss 2.065933
# iteration 1400 / 1500: loss 2.049480
# iteration 0 / 1500: loss 713.777708
# iteration 100 / 1500: loss 113.284774
# iteration 200 / 1500: loss 19.481031
# iteration 300 / 1500: loss 4.823740
# iteration 400 / 1500: loss 2.540513
# iteration 500 / 1500: loss 2.154786
# iteration 600 / 1500: loss 2.100223
# iteration 700 / 1500: loss 2.138939
# iteration 800 / 1500: loss 2.145180
# iteration 900 / 1500: loss 2.090214
# iteration 1000 / 1500: loss 2.042868
# iteration 1100 / 1500: loss 2.063974
# iteration 1200 / 1500: loss 2.061994
# iteration 1300 / 1500: loss 2.048526
# iteration 1400 / 1500: loss 2.043483
# iteration 0 / 1500: loss 745.137282
# iteration 100 / 1500: loss 109.346954
# iteration 200 / 1500: loss 17.508284
# iteration 300 / 1500: loss 4.278340
# iteration 400 / 1500: loss 2.398054
# iteration 500 / 1500: loss 2.099175
# iteration 600 / 1500: loss 2.036414
# iteration 700 / 1500: loss 2.097775
# iteration 800 / 1500: loss 2.110113
# iteration 900 / 1500: loss 2.068390
# iteration 1000 / 1500: loss 2.108271
# iteration 1100 / 1500: loss 2.079876
# iteration 1200 / 1500: loss 2.111769
# iteration 1300 / 1500: loss 2.106297
# iteration 1400 / 1500: loss 2.071201
# iteration 0 / 1500: loss 768.855941
# iteration 100 / 1500: loss 103.933958
# iteration 200 / 1500: loss 15.583790
# iteration 300 / 1500: loss 3.913924
# iteration 400 / 1500: loss 2.347613
# iteration 500 / 1500: loss 2.187442
# iteration 600 / 1500: loss 2.140587
# iteration 700 / 1500: loss 2.129674
# iteration 800 / 1500: loss 2.087315
# iteration 900 / 1500: loss 2.090954
# iteration 1000 / 1500: loss 2.080509
# iteration 1100 / 1500: loss 2.070994
# iteration 1200 / 1500: loss 2.063737
# iteration 1300 / 1500: loss 2.021484
# iteration 1400 / 1500: loss 2.075907
# iteration 0 / 1500: loss 817.999367
# iteration 100 / 1500: loss 102.136515
# iteration 200 / 1500: loss 14.337637
# iteration 300 / 1500: loss 3.615621
# iteration 400 / 1500: loss 2.288581
# iteration 500 / 1500: loss 2.092862
# iteration 600 / 1500: loss 2.103158
# iteration 700 / 1500: loss 2.133498
# iteration 800 / 1500: loss 2.047887
# iteration 900 / 1500: loss 2.055660
# iteration 1000 / 1500: loss 2.070008
# iteration 1100 / 1500: loss 2.068085
# iteration 1200 / 1500: loss 2.098629
# iteration 1300 / 1500: loss 2.134979
# iteration 1400 / 1500: loss 2.088117
# iteration 0 / 1500: loss 678.097130
# iteration 100 / 1500: loss 97.807801
# iteration 200 / 1500: loss 15.701310
# iteration 300 / 1500: loss 3.950324
# iteration 400 / 1500: loss 2.360699
# iteration 500 / 1500: loss 2.086267
# iteration 600 / 1500: loss 2.100648
# iteration 700 / 1500: loss 2.074746
# iteration 800 / 1500: loss 2.103731
# iteration 900 / 1500: loss 2.093314
# iteration 1000 / 1500: loss 2.081778
# iteration 1100 / 1500: loss 2.068091
# iteration 1200 / 1500: loss 2.080078
# iteration 1300 / 1500: loss 2.033695
# iteration 1400 / 1500: loss 2.085885
# iteration 0 / 1500: loss 711.404689
# iteration 100 / 1500: loss 94.042015
# iteration 200 / 1500: loss 13.993285
# iteration 300 / 1500: loss 3.642784
# iteration 400 / 1500: loss 2.299883
# iteration 500 / 1500: loss 2.122508
# iteration 600 / 1500: loss 2.104572
# iteration 700 / 1500: loss 2.112132
# iteration 800 / 1500: loss 2.103842
# iteration 900 / 1500: loss 2.051004
# iteration 1000 / 1500: loss 2.099041
# iteration 1100 / 1500: loss 2.072731
# iteration 1200 / 1500: loss 2.118473
# iteration 1300 / 1500: loss 2.074617
# iteration 1400 / 1500: loss 2.069033
# iteration 0 / 1500: loss 739.511253
# iteration 100 / 1500: loss 89.694372
# iteration 200 / 1500: loss 12.481435
# iteration 300 / 1500: loss 3.334548
# iteration 400 / 1500: loss 2.295073
# iteration 500 / 1500: loss 2.111939
# iteration 600 / 1500: loss 2.098634
# iteration 700 / 1500: loss 2.102951
# iteration 800 / 1500: loss 2.075898
# iteration 900 / 1500: loss 2.061232
# iteration 1000 / 1500: loss 2.083726
# iteration 1100 / 1500: loss 2.097572
# iteration 1200 / 1500: loss 2.124964
# iteration 1300 / 1500: loss 2.062646
# iteration 1400 / 1500: loss 2.061778
# iteration 0 / 1500: loss 779.354080
# iteration 100 / 1500: loss 86.543481
# iteration 200 / 1500: loss 11.268587
# iteration 300 / 1500: loss 3.069880
# iteration 400 / 1500: loss 2.170277
# iteration 500 / 1500: loss 2.120859
# iteration 600 / 1500: loss 2.106482
# iteration 700 / 1500: loss 2.115917
# iteration 800 / 1500: loss 2.114824
# iteration 900 / 1500: loss 2.044997
# iteration 1000 / 1500: loss 2.116789
# iteration 1100 / 1500: loss 2.052665
# iteration 1200 / 1500: loss 2.140824
# iteration 1300 / 1500: loss 2.075436
# iteration 1400 / 1500: loss 2.016496
# iteration 0 / 1500: loss 797.165948
# iteration 100 / 1500: loss 80.991176
# iteration 200 / 1500: loss 9.976804
# iteration 300 / 1500: loss 2.942083
# iteration 400 / 1500: loss 2.203254
# iteration 500 / 1500: loss 2.121998
# iteration 600 / 1500: loss 2.083313
# iteration 700 / 1500: loss 2.088646
# iteration 800 / 1500: loss 2.039892
# iteration 900 / 1500: loss 2.073877
# iteration 1000 / 1500: loss 2.100395
# iteration 1100 / 1500: loss 2.160813
# iteration 1200 / 1500: loss 2.149836
# iteration 1300 / 1500: loss 2.124548
# iteration 1400 / 1500: loss 2.109869
# lr 1.600000e-07 reg 2.200000e+04 train accuracy: 0.336551 val accuracy: 0.355000
# lr 1.600000e-07 reg 2.300000e+04 train accuracy: 0.335571 val accuracy: 0.347000
# lr 1.600000e-07 reg 2.400000e+04 train accuracy: 0.328694 val accuracy: 0.345000
# lr 1.600000e-07 reg 2.500000e+04 train accuracy: 0.329000 val accuracy: 0.342000
# lr 1.600000e-07 reg 2.600000e+04 train accuracy: 0.328469 val accuracy: 0.346000
# lr 1.800000e-07 reg 2.200000e+04 train accuracy: 0.333531 val accuracy: 0.358000
# lr 1.800000e-07 reg 2.300000e+04 train accuracy: 0.332163 val accuracy: 0.348000
# lr 1.800000e-07 reg 2.400000e+04 train accuracy: 0.330000 val accuracy: 0.341000
# lr 1.800000e-07 reg 2.500000e+04 train accuracy: 0.329776 val accuracy: 0.341000
# lr 1.800000e-07 reg 2.600000e+04 train accuracy: 0.325327 val accuracy: 0.337000
# lr 2.000000e-07 reg 2.200000e+04 train accuracy: 0.333653 val accuracy: 0.340000
# lr 2.000000e-07 reg 2.300000e+04 train accuracy: 0.334204 val accuracy: 0.352000
# lr 2.000000e-07 reg 2.400000e+04 train accuracy: 0.329122 val accuracy: 0.341000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.330592 val accuracy: 0.347000
# lr 2.000000e-07 reg 2.600000e+04 train accuracy: 0.327122 val accuracy: 0.341000
# lr 2.200000e-07 reg 2.200000e+04 train accuracy: 0.337694 val accuracy: 0.348000
# lr 2.200000e-07 reg 2.300000e+04 train accuracy: 0.323980 val accuracy: 0.337000
# lr 2.200000e-07 reg 2.400000e+04 train accuracy: 0.333224 val accuracy: 0.346000
# lr 2.200000e-07 reg 2.500000e+04 train accuracy: 0.329898 val accuracy: 0.345000
# lr 2.200000e-07 reg 2.600000e+04 train accuracy: 0.326000 val accuracy: 0.341000
# best validation accuracy achieved during cross-validation: 0.358000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.343000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
